# %% [markdown]
# # Merged Data Feature Engineering
#
# This file constructs relevant variables

# %%
# %run Boston_311_Master_Merger.ipynb
# Out:
# /var/folders/5m/kgrgm7ns0q10f7dp56dv4ylm0000gn/T/ipykernel_26818/2703879238.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(url) for url in urls]
# FS : 2015-06-15 00:00:00
# LS : 2022-11-13 00:00:00
# Min dt: 2015-06-15 00:00:00
# Max dt: 2022-11-13 00:00:00
# Number of Rows:  1864777
# Number of Columns:  31
# Number of Rows:  581
# Number of Columns:  62
# /var/folders/5m/kgrgm7ns0q10f7dp56dv4ylm0000gn/T/ipykernel_26818/3125038471.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_dfs = [pd.read_csv(url) for url in crime_urls]
# /var/folders/5m/kgrgm7ns0q10f7dp56dv4ylm0000gn/T/ipykernel_26818/3125038471.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_dfs = [pd.read_csv(url) for url in crime_urls]
# ...

# %%
whos
# Out:
# Variable     Type            Data/Info
# --------------------------------------
# bc           str             https://data.boston.gov/d<...>nsus-block-group-data.csv
# bcb          GeoDataFrame         FID  OBJECTID STATEF<...>\n[581 rows x 17 columns]
# bn_url       str             https://data.boston.gov/d<...>s2020_blockgroups.geojson
# c_cj         DataFrame                 GEOID20  ucr_on<...>n\n[580 rows x 4 columns]
# cgdf         GeoDataFrame           INCIDENT_NUMBER  O<...>175724 rows x 20 columns]
# cgdf_j       GeoDataFrame           INCIDENT_NUMBER  O<...>165398 rows x 37 columns]
# crime_dfs    list            n=8
# crime_urls   list            n=8
# datetime     type            <class 'datetime.datetime'>
# df_311       DataFrame                case_enquiry_id <...>864777 rows x 30 columns]
# df_311_rf    GeoDataFrame             case_enquiry_id <...>864777 rows x 32 columns]
# df_bc        DataFrame       0   field concept State/U<...>\n[581 rows x 45 columns]
# ...

# %%
master.describe()
# Out:
#        case_enquiry_id  location_zipcode      latitude     longitude  \
# count     1.864777e+06      1.429112e+06  1.864777e+06  1.864777e+06
# mean      1.010029e+11      2.127032e+03  4.233374e+01 -7.107788e+01
# std       8.794964e+05      1.886291e+01  3.271510e-02  3.327244e-02
# min       1.010014e+11      2.108000e+03  4.223020e+01 -7.118540e+01
# 25%       1.010022e+11      2.119000e+03  4.231140e+01 -7.109300e+01
# 50%       1.010029e+11      2.125000e+03  4.234360e+01 -7.106620e+01
# 75%       1.010037e+11      2.130000e+03  4.235940e+01 -7.105870e+01
# max       1.010046e+11      2.467000e+03  4.239520e+01 -7.099490e+01
#
#             avgprcp   index_right           FID      OBJECTID       ALAND20  \
# count  1.592235e+06  1.864698e+06  1.864698e+06  1.864698e+06  1.864698e+06
# mean   2.868853e+01  2.425821e+02  3.281316e+02  3.291316e+02  2.654462e+05
# std    7.559741e+01  1.511714e+02  1.680441e+02  1.680441e+02  2.317495e+05
# ...
